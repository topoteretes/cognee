# %% [markdown]
# # Using Cognee with Python Development Data
#
# Unite authoritative Python practice (Guido van Rossum's own contributions!), normative guidance (Zen/PEP 8), and your lived context (rules + conversations) into one *AI memory* that produces answers that are relevant, explainable, and consistent.

# %% [markdown]
# ## What You'll Learn
#
# In this comprehensive tutorial, you'll discover how to transform scattered development data into an intelligent knowledge system that enhances your coding workflow. By the end, you'll have:
#
# - **Connected disparate data sources** (Guido's CPython contributions, mypy development, PEP discussions, your Python projects) into a unified AI memory graph
# - **Built an memory layer** that understands Python design philosophy, best practice coding patterns, and your preferences and experience
# - **Learn how to use intelligent search capabilities** that combine the diverse context
# - **Integrated everything with your coding environment** through MCP (Model Context Protocol)
#
# This tutorial demonstrates the power of **knowledge graphs** and **retrieval-augmented generation (RAG)** for software development, showing you how to build systems that learn from Python's creator and improve your own Python development.

# %% [markdown]
# ## Cognee and its core operations
#
# Before we dive in, let's understand the core Cognee operations we'll be working with:
#
# - **`cognee.add()`** - Ingests raw data (files, text, APIs) into the system
# - **`cognee.cognify()`** - Processes and structures data into a knowledge graph using AI
# - **`cognee.search()`** - Queries the knowledge graph with natural language or Cypher
# - **`cognee.memify()`** - Cognee's "secret sauce" that infers implicit connections and rules from your data

# %% [markdown]
# ## Data used in this tutorial
#
# Cognee can ingest many types of sources. In this tutorial, we use a small, concrete set of files that cover different perspectives:
#
# - **`guido_contributions.json` — Authoritative exemplars.** Real PRs and commits from Guido van Rossum (mypy, CPython). These show how Python’s creator solved problems and provide concrete anchors for patterns.
# - **`pep_style_guide.md` — Norms.** Encodes community style and typing conventions (PEP 8 and related). Ensures that search results and inferred rules align with widely accepted standards.
# - **`zen_principles.md` — Philosophy.** The Zen of Python. Grounds design trade‑offs (simplicity, explicitness, readability) beyond syntax or mechanics.
# - **`my_developer_rules.md` — Local constraints.** Your house rules, conventions, and project‑specific requirements (scope, privacy, Spec.md). Keeps recommendations relevant to your actual workflow.
# - **`copilot_conversations.json` — Personal history.** Transcripts of real assistant conversations, including your questions, code snippets, and discussion topics. Captures “how you code” and connects it to “how Guido codes.”

# %% [markdown]
# # Prelinimiaries
#
# Cognee relies heavily on async functions.
# We need `nest_asyncio` so `await` works in this notebook.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# We will do a quick import check.

# %%
import cognee
import os
from pathlib import Path

print('🔍 Quick Cognee Import Check')
print('=' * 30)
print(f'📍 Cognee location: {cognee.__file__}')
print(f'📁 Package directory: {os.path.dirname(cognee.__file__)}')

# Check if it's local or installed
current_dir = Path.cwd()
cognee_path = Path(cognee.__file__)
if current_dir in cognee_path.parents:
    print('🏠 Status: LOCAL DEVELOPMENT VERSION')
else:
    print('📦 Status: INSTALLED PACKAGE')
# Out:
# 🔍 Quick Cognee Import Check
# ==============================
# 📍 Cognee location: /Users/lazar/PycharmProjects/cognee/cognee/__init__.py
# 📁 Package directory: /Users/lazar/PycharmProjects/cognee/cognee
# 📦 Status: INSTALLED PACKAGE

# %% [markdown]
# And just to be safe, we will make sure that the path contains the root directory, so Python can find everything it needs to run the notebook.

# %%
import sys
from pathlib import Path
notebook_dir = Path.cwd()
if notebook_dir.name == 'notebooks':
    project_root = notebook_dir.parent
else:
    project_root = Path.cwd()

# Add project root to the beginning of sys.path
project_root_str = str(project_root.absolute())
if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)

print(f"📁 Project root: {project_root_str}")
# Out:
# 📁 Project root: /Users/lazar/PycharmProjects/cognee

# %% [markdown]
# Finally, we will begin with a clean slate, by removing any previous Cognee data:

# %%
await cognee.prune.prune_data()
await cognee.prune.prune_system(metadata=True)
# Out:
# 2025-09-07T12:05:41.226643 [info     ] Database deleted successfully. [cognee.shared.logging_utils]

# %% [markdown]
# ### Exploring Guido's Python Contributions
#
# We'll begin with a document that contains detailed PRs and commits from Guido van Rossum's work on mypy and CPython, showing real-world examples of Python's creator solving type system and language design challenges.
#
# We'll use Cognee's `add()` and `cognify()` functions to ingest this data and build a knowledge graph that connects Guido's development patterns with Python best practices.

# %%
import cognee
result = await cognee.add(
    "file://data/guido_contributions.json",
    node_set=["guido"]
)
await cognee.cognify()
results = await cognee.search("Show me commits")
# Out:
# User a35adc78-d4bb-42da-ad0b-3ad52fc222e7 has registered.
# EmbeddingRateLimiter initialized: enabled=False, requests_limit=60, interval_seconds=60
#
# 2025-09-07T11:54:59.663413 [info     ] Pipeline run started: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:54:59.664064 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:54:59.664466 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:54:59.678662 [info     ] Registered loader: pypdf_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-09-07T11:54:59.679216 [info     ] Registered loader: text_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-09-07T11:54:59.679596 [info     ] Registered loader: image_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-09-07T11:54:59.679951 [info     ] Registered loader: audio_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-09-07T11:54:59.680260 [info     ] Registered loader: unstructured_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-09-07T11:54:59.692179 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:54:59.692997 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:54:59.693329 [info     ] Pipeline run completed: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:54:59.708125 [info     ] Ontology file 'None' not found. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2025-09-07T11:54:59.729261 [info     ] Pipeline run started: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:54:59.729906 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:54:59.730351 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:54:59.739549 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:54:59.821323 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:55:10.803782 [info     ] No close match found for 'softwarechange' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.807972 [info     ] No close match found for 're-work indirect dependencies' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.809182 [info     ] No close match found for 'softwareproject' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.810180 [info     ] No close match found for 'mypy' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.811212 [info     ] No close match found for 'prnumber' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.812692 [info     ] No close match found for '19798' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.813773 [info     ] No close match found for 'concept' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.814819 [info     ] No close match found for 'files changed' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.815754 [info     ] No close match found for 'indirect dependencies' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.816530 [info     ] No close match found for 'codecomponent' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.817383 [info     ] No close match found for 'typeindirectionvisitor' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.818102 [info     ] No close match found for 'process' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.818890 [info     ] No close match found for 'semantic analysis' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.819643 [info     ] No close match found for 'performance impact' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.820298 [info     ] No close match found for 'fixes' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.821052 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.821569 [info     ] No close match found for '2025-09-05' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.822748 [info     ] No close match found for 'file' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.823523 [info     ] No close match found for 'mypy/indirection.py changes' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.823901 [info     ] No close match found for 'mypy/nodes.py changes' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.824273 [info     ] No close match found for 'typealiastype' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.824599 [info     ] No close match found for 'instance' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.824933 [info     ] No close match found for 'variable' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.825219 [info     ] No close match found for 'seen_aliases' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.825488 [info     ] No close match found for 'seen_types' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.826183 [info     ] No close match found for 'seen_fullnames' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.826657 [info     ] No close match found for 'modules' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.826987 [info     ] No close match found for 'project' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.827334 [info     ] No close match found for 'pullrequest' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.827632 [info     ] No close match found for 'chore: add cline_docs/ to .gitignore' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.827911 [info     ] No close match found for '[mypyc] add type annotations to tests' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.828178 [info     ] No close match found for 'check functions without annotations in mypyc tests' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.828778 [info     ] No close match found for 'fix: allow instantiation of type[none] in analyze_type_type_callee' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.829118 [info     ] No close match found for 'mypy pr 19782' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.829426 [info     ] No close match found for 'issue' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.829708 [info     ] No close match found for 'issue 19660' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.830029 [info     ] No close match found for 'mypy/checkexpr.py' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.830317 [info     ] No close match found for 'testcase' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.830604 [info     ] No close match found for 'testtypeusingtypecnonetype' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.830860 [info     ] No close match found for 'mypyc pr 19217' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.831165 [info     ] No close match found for 'mypyc/primitives/weakref_ops.py' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.831451 [info     ] No close match found for 'commit' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.831747 [info     ] No close match found for 'cpython commit 28625d4f' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.831977 [info     ] No close match found for '2025-09-02' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.832241 [info     ] No close match found for 'gh-118335' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.832462 [info     ] No close match found for 'rename --experimental-interpreter on windows to --experimental-jit-interpreter' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.832901 [info     ] No close match found for 'document' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.833298 [info     ] No close match found for 'doc/whatsnew/3.13.rst' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.833553 [info     ] No close match found for 'pcbuild/build.bat' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.833875 [info     ] No close match found for 'pep' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.834104 [info     ] No close match found for 'pep 667' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.834438 [info     ] No close match found for 'attribute' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.834646 [info     ] No close match found for 'frame.f_locals' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.834950 [info     ] No close match found for 'write-through proxy' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.835311 [info     ] No close match found for 'typeguard (pep 647)' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.835796 [info     ] No close match found for 'mypy: support typeguard (pep 647)' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.836117 [info     ] No close match found for 'software' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:55:10.836381 [info     ] No close match found for '.github/issue_template/crash.md' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.836676 [info     ] No close match found for '.github/issue_template/bug.md' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.836932 [info     ] No close match found for 'mypy/config_parser.py' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.837324 [info     ] No close match found for 'commit_cca6e2f' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.837927 [info     ] No close match found for 'commit_6f07cb6' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.838309 [info     ] No close match found for 'commit_9d03846' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.838653 [info     ] No close match found for 'commit_57d3473' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:10.838967 [info     ] No close match found for 'commit_42a5220' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:55:14.763168 [info     ] Retrieved 70 nodes and 156 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:55:15.500077 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:55:19.781997 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:55:23.577888 [info     ] Retrieved 76 nodes and 209 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:55:24.515648 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:55:24.516093 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:55:24.516397 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:55:24.516754 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:55:24.517062 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:55:24.517361 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:55:24.517606 [info     ] Pipeline run completed: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:55:24.550762 [info     ] Retrieved 76 nodes and 209 edges in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:55:24.552178 [info     ] Graph projection completed: 76 nodes, 209 edges in 0.02s [CogneeGraph]
#
# 2025-09-07T11:55:24.995660 [info     ] Vector collection retrieval completed: Retrieved distances from 6 collections in 0.03s [cognee.shared.logging_utils]

# %%
print(results[0])
# Out:
# Showing commits for repository 'mypy':

# %% [markdown]
# ### What's just happened?
# The `search()` function uses natural language to query a knowledge graph containing Guido's development history.
# Unlike traditional databases, Cognee understands the relationships between commits, language features, design decisions, and evolution over time.
#
# Cognee also allows you to visualize the graphs created:

# %%
from cognee import visualize_graph
await visualize_graph('./guido_contributions.html')
# Out:
# 2025-09-07T11:55:38.519644 [info     ] Retrieved 76 nodes and 209 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:55:38.522646 [info     ] Graph visualization saved as ./guido_contributions.html [cognee.shared.logging_utils]
#
# 2025-09-07T11:55:38.523615 [info     ] The HTML file has been stored at path: ./guido_contributions.html [cognee.shared.logging_utils]
# '\n    <!DOCTYPE html>\n    <html>\n    <head>\n        <meta charset="utf-8">\n        <script src="https://d3js.org/d3.v5.min.js"></script>\n        <style>\n            body, html { margin: 0; padding: 0; width: 100%; height: 100%; overflow: hidden; background: linear-gradient(90deg, #101010, #1a1a2e); color: white; font-family: \'Inter\', sans-serif; }\n\n            svg { width: 100vw; height: 100vh; display: block; }\n            .links line { stroke: rgba(255, 255, 255, 0.4); stroke-width: 2px; }\n            .links line.weighted { stroke: rgba(255, 215, 0, 0.7); }\n            .links line.multi-weighted { stroke: rgba(0, 255, 127, 0.8); }\n            .nodes circle { stroke: white; stroke-width: 0.5px; filter: drop-shadow(0 0 5px rgba(255,255,255,0.3)); }\n            .node-label { font-size: 5px; font-weight: bold; fill: white; text-anchor: middle; dominant-baseline: middle; font-family: \'Inter\', sans-serif; pointer-events: none; }\n            .edge-label { font-size: 3px; fill: rgba(255, 255, 255, 0.7); text-anchor: middle; dominant-baseline: middle; font-family: \'Inter\', sans-serif; pointer-events: none; }\n            \n            .tooltip {\n                position: absolute;\n                text-align: left;\n                padding: 8px;\n                font-size: 12px;\n                background: rgba(0, 0, 0, 0.9);\n                color: white;\n                border: 1px solid rgba(255, 255, 255, 0.3);\n                border-radius: 4px;\n                pointer-events: none;\n                opacity: 0;\n                transition: opacity 0.2s;\n                z-index: 1000;\n                max-width: 300px;\n                word-wrap: break-word;\n            }\n        </style>\n    </head>\n    <body>\n        <svg></svg>\n        <div class="tooltip" id="tooltip"></div>\n        <script>\n            var nodes = [{"id": "cfac008a-590d-532e-bc8e-42ae7b8bfb5f", "text": "[\\n  {\\n    \\"type\\": \\"pr\\",\\n    \\"repository\\": \\"mypy\\",\\n    \\"title\\": \\"Re-work indirect dependencies\\",\\n    \\"description\\": \\"Wow, this was quite a ride. Indirect dependencies were always supported kind of on best effort. This PR puts them on some principled foundation. It fixes three crashes and three stale types reported. All tests are quite weird/obscure, they are designed to expose the flaws in current logic (plus one test that passes on master, but it covers important corner case, so I add it just in case ). A short summary of various fixes (in arbitrary order):\\\\r\\\\n* Update many outdated comments and docstrings\\\\r\\\\n* Missing transitive dependency is now considered stale\\\\r\\\\n* Handle transitive generic bases in indirection visitor\\\\r\\\\n* Handle chained alias targets in indirection visitor\\\\r\\\\n* Always record original aliases during semantic analysis\\\\r\\\\n* Delete `qualified_tvars` as a concept, they are not needed since long ago\\\\r\\\\n* Remove ad-hoc handling for `TypeInfo`s from `build.py`\\\\r\\\\n* Support symbols with setter type different from getter type\\\\r\\\\n\\\\r\\\\nIn general the logic should be more simple/straightforward now:\\\\r\\\\n* Get all types in a file (need both symbol types _and_ expression types since some types may be only local)\\\\r\\\\n* For each type _transitively_ find all named types in them (thus aggregating all interfaces the type depends on)\\\\r\\\\n* In case any type was forced using `get_proper_type()`, record the orginal type alias during semantic analysis\\\\r\\\\n\\\\r\\\\nNote since this makes the algorithm correct, it may also make it slower (most notably because we must visit generic bases). I tried to offset this by couple optimizations, hopefully performance impact will be minimal.\\",\\n    \\"url\\": \\"https://github.com/python/mypy/pull/19798\\",\\n    \\"date\\": \\"2025-09-05T13:54:52Z\\",\\n    \\"sha_or_number\\": \\"19798\\",\\n    \\"files_changed\\": [\\n      \\"mypy/build.py\\",\\n      \\"mypy/fixup ...

# %%
from IPython.display import IFrame, HTML, display
display(IFrame("./guido_contributions.html", width="100%", height="500"))
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="./guido_contributions.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **Why visualization matters:** Knowledge graphs reveal hidden patterns in data. In this case, patterins in Guido's contributions to Python's development. The interactive visualization shows how different projects (CPython, mypy, PEPs), features, and time periods connect - insights that show Python's thoughtful evolution.
#
# Take a moment to explore the graph. Notice how:
#
# - CPython core development clusters around 2020
# - Mypy contributions focus on fixtures and run classes
# - PEP discussions mention Thomas Grainiger and Adam Turner
# - Time-based connections show how ideas evolved into features

# %% [markdown]
# Now we'll add the remaining data and see how they connections emerge between Guido's contributions, Python best practices, and user conversations.

# %%
await cognee.add("file://data/copilot_conversations.json", node_set=["developer_data"])
await cognee.add("file://data/my_developer_rules.md", node_set=["developer_data"])
await cognee.add("file://data/zen_principles.md", node_set=["principles_data"])
await cognee.add("file://data/pep_style_guide.md", node_set=["principles_data"])

await cognee.cognify()
# Out:
# 2025-09-07T11:56:03.636275 [info     ] Pipeline run started: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.637065 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.637392 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.652328 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.652727 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.653007 [info     ] Pipeline run completed: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.711636 [info     ] Pipeline run started: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.712201 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.712555 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.723866 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.724268 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.724611 [info     ] Pipeline run completed: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.755905 [info     ] Pipeline run started: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.756284 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.756685 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.767895 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.768252 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.768520 [info     ] Pipeline run completed: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.801806 [info     ] Pipeline run started: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.802166 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.802468 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.812704 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.813054 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-09-07T11:56:03.813379 [info     ] Pipeline run completed: `f5ca7c7d-08ef-584f-a745-891dcc728073` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.820869 [info     ] Ontology file 'None' not found. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2025-09-07T11:56:03.838218 [info     ] Pipeline run started: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.838593 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.838956 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:03.840133 [info     ] Pipeline run started: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.840463 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.840788 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:03.841272 [info     ] Pipeline run started: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.841545 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.841774 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:03.842389 [info     ] Pipeline run started: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:03.842624 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.843063 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:03.856804 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.862163 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.864341 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.867652 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:03.878616 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.905587 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.915328 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:03.940779 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:07.294325 [info     ] No close match found for 'document' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:07.295957 [info     ] No close match found for 'assistant guidelines' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:07.296933 [info     ] No close match found for 'spec.md' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:09.092344 [info     ] Retrieved 80 nodes and 214 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:09.774410 [info     ] No close match found for 'concept' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:09.775032 [info     ] No close match found for 'the zen of python' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:09.775519 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:09.775956 [info     ] No close match found for 'tim peters' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:09.776405 [info     ] No close match found for 'principles' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:09.776843 [info     ] No close match found for 'modern python tie-ins' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:09.777435 [info     ] No close match found for 'quick review checklist' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:10.061598 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:11.577685 [info     ] Retrieved 88 nodes and 226 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:12.551947 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:12.894396 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:13.937846 [info     ] No close match found for 'styleguide' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:13.939242 [info     ] No close match found for 'pep 8 style guide' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.940158 [info     ] No close match found for 'concept' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:13.941087 [info     ] No close match found for 'code layout' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.941932 [info     ] No close match found for 'imports' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.942672 [info     ] No close match found for 'whitespace' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.943424 [info     ] No close match found for 'naming' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.944069 [info     ] No close match found for 'comments and docstrings' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.944700 [info     ] No close match found for 'type hints' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.945319 [info     ] No close match found for 'tooling' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.945917 [info     ] No close match found for 'common violations' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.946485 [info     ] No close match found for 'codeexample' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:13.947083 [info     ] No close match found for 'hanging indent example' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.947625 [info     ] No close match found for 'imports example' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.948310 [info     ] No close match found for 'whitespace example' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.948788 [info     ] No close match found for 'docstring example' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.990684 [info     ] No close match found for 'concept' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:13.991329 [info     ] No close match found for 'async/await patterns' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.991704 [info     ] No close match found for 'library' in category 'classes' [OntologyAdapter]
#
# 2025-09-07T11:56:13.992055 [info     ] No close match found for 'aiohttp' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.992374 [info     ] No close match found for 'semaphore' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.992681 [info     ] No close match found for 'context manager' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.992975 [info     ] No close match found for 'pydantic' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.993285 [info     ] No close match found for 'dataclass' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.993583 [info     ] No close match found for 'fastapi' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.993908 [info     ] No close match found for 'pytest-asyncio' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.994174 [info     ] No close match found for 'performance optimization' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.994529 [info     ] No close match found for 'error handling' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.994733 [info     ] No close match found for 'tcpconnector' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.995023 [info     ] No close match found for 'retry logic' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.995271 [info     ] No close match found for 'html parsing' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:13.995562 [info     ] No close match found for 'sqlalchemy' in category 'individuals' [OntologyAdapter]
#
# 2025-09-07T11:56:14.912139 [info     ] Retrieved 89 nodes and 231 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:15.661925 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:15.816155 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:15.816765 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:15.817045 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:15.817451 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:15.817758 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:15.817988 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:15.818206 [info     ] Pipeline run completed: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:15.884291 [info     ] Retrieved 106 nodes and 260 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:16.096303 [info     ] Retrieved 123 nodes and 287 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:17.216211 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:17.273588 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:18.281748 [info     ] Retrieved 124 nodes and 312 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:19.288421 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:19.288925 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:19.289246 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:19.289608 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:19.289921 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:19.290242 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:19.290464 [info     ] Pipeline run completed: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:21.079114 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:21.108303 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:23.441693 [info     ] Retrieved 126 nodes and 314 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:23.453053 [info     ] Retrieved 126 nodes and 314 edges in 0.05 seconds [Neo4jAdapter]
#
# 2025-09-07T11:56:24.411975 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:24.412403 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:24.412745 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:24.413023 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:24.413307 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:24.413565 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:24.413803 [info     ] Pipeline run completed: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:56:24.429816 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-09-07T11:56:24.430172 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-09-07T11:56:24.430413 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-09-07T11:56:24.430683 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-09-07T11:56:24.430929 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-09-07T11:56:24.431204 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-09-07T11:56:24.431443 [info     ] Pipeline run completed: `7233180e-8575-54d0-bee4-700ba5f5de42` [run_tasks_with_telemetry()]
# {UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'): PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('7cef3d5b-e7fe-5fb1-ad08-43ff407c9e44'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=[{'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('7cef3d5b-e7fe-5fb1-ad08-43ff407c9e44'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('06812f34-2873-557f-86c9-debcc5b618c9')}, {'run_info': PipelineRunAlreadyCompleted(status='PipelineRunAlreadyCompleted', pipeline_run_id=UUID('7cef3d5b-e7fe-5fb1-ad08-43ff407c9e44'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('0e3b3446-ba35-5c74-a491-eac47acc6d98')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('7cef3d5b-e7fe-5fb1-ad08-43ff407c9e44'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('27467b8e-9b7c-5ca1-9b2e-0d2ca315446f')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('7cef3d5b-e7fe-5fb1-ad08-43ff407c9e44'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('460f2065-b267-56f7-a1c0-c7515d326dac')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('7cef3d5b-e7fe-5fb1-ad08-43ff407c9e44'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('c20e772c-9313-57af-974b-2068cdfe19e8')}])}

# %%
results = await cognee.search(
    "What Python type hinting challenges did I face, and how does Guido approach similar problems in mypy?",
    query_type=cognee.SearchType.GRAPH_COMPLETION
)
print(results)
# Out:
# 2025-09-07T12:02:47.514797 [info     ] Retrieved 158 nodes and 379 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T12:02:47.517739 [info     ] Graph projection completed: 158 nodes, 379 edges in 0.03s [CogneeGraph]
#
# 2025-09-07T12:02:48.187870 [info     ] Vector collection retrieval completed: Retrieved distances from 6 collections in 0.02s [cognee.shared.logging_utils]
# ['Acknowledged.']

# %% [markdown]
# You'll see that cognee has connected your Python development challenges with Guido's approaches, revealing patterns like:
#
# - "Type hint implementation failed due to circular imports - similar to issue Guido solved in mypy PR #1234"
# - "Performance bottleneck in list comprehension matches pattern Guido optimized in CPython commit abc123"

# %% [markdown]
# Let's now introduce the memory functions. These algorithms run on top of your semantic layer, connecting the dots and improving the search.
#
# Memify is customizable and can use any transformation you'd like to write. But it also requires

# %%
await cognee.memify()
# Out:
# 2025-09-07T11:57:54.862996 [info     ] Retrieved 126 nodes and 314 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:57:54.865110 [info     ] Graph projection completed: 126 nodes, 314 edges in 0.03s [CogneeGraph]
#
# 2025-09-07T11:57:54.886755 [info     ] Pipeline run started: `af2e3872-55fb-5cbb-b0dc-0a13d0b9b1bd` [run_tasks_with_telemetry()]
#
# 2025-09-07T11:57:54.887389 [info     ] Async Generator task started: `extract_subgraph_chunks` [run_tasks_base]
#
# 2025-09-07T11:57:54.887914 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:04.375679 [info     ] Retrieved 131 nodes and 318 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:05.428516 [info     ] Retrieved 131 nodes and 322 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:06.414586 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:06.415131 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:06.431621 [info     ] Retrieved 5 nodes and 4 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:13.285793 [info     ] Retrieved 134 nodes and 325 edges in 0.06 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:14.299334 [info     ] Retrieved 134 nodes and 328 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:15.255634 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:15.256386 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:15.278329 [info     ] Retrieved 8 nodes and 7 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:24.608953 [info     ] Retrieved 139 nodes and 333 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:25.817327 [info     ] Retrieved 139 nodes and 338 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:26.805980 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:26.806649 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:26.822555 [info     ] Retrieved 13 nodes and 12 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:35.652805 [info     ] Retrieved 142 nodes and 341 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:36.686147 [info     ] Retrieved 142 nodes and 344 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:37.699798 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:37.700712 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:37.718775 [info     ] Retrieved 16 nodes and 15 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:51.576721 [info     ] Retrieved 145 nodes and 347 edges in 0.07 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:52.568566 [info     ] Retrieved 145 nodes and 350 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:58:53.516969 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:53.517455 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:58:53.542532 [info     ] Retrieved 19 nodes and 18 edges for NodeSet in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:08.426235 [info     ] Retrieved 148 nodes and 353 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:09.560436 [info     ] Retrieved 148 nodes and 356 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:10.503615 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:10.504130 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:10.513761 [info     ] Retrieved 22 nodes and 21 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:16.601704 [info     ] Retrieved 151 nodes and 359 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:17.605849 [info     ] Retrieved 151 nodes and 362 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:18.869401 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:18.870007 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:18.882199 [info     ] Retrieved 25 nodes and 24 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:24.709820 [info     ] Retrieved 151 nodes and 362 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:25.731473 [info     ] Retrieved 151 nodes and 365 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:26.769884 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:26.770412 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:26.782453 [info     ] Retrieved 25 nodes and 24 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:33.591001 [info     ] Retrieved 154 nodes and 368 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:35.111361 [info     ] Retrieved 154 nodes and 371 edges in 0.02 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:35.719330 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:35.719937 [info     ] Coroutine task started: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:35.732641 [info     ] Retrieved 28 nodes and 27 edges for NodeSet in 0.01 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:43.575467 [info     ] Retrieved 158 nodes and 375 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:44.732779 [info     ] Retrieved 158 nodes and 379 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T11:59:45.326267 [info     ] Coroutine task completed: `add_rule_associations` [run_tasks_base]
#
# 2025-09-07T11:59:45.326932 [info     ] Async Generator task completed: `extract_subgraph_chunks` [run_tasks_base]
#
# 2025-09-07T11:59:45.327231 [info     ] Pipeline run completed: `af2e3872-55fb-5cbb-b0dc-0a13d0b9b1bd` [run_tasks_with_telemetry()]
# {UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'): PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('85d185c7-8cf8-5e85-9894-7938a80c9acf'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=[{'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('85d185c7-8cf8-5e85-9894-7938a80c9acf'), dataset_id=UUID('727f2c35-93eb-57f9-8f66-8856c9ae95e3'), dataset_name='main_dataset', payload=None, data_ingestion_info=None)}])}

# %% [markdown]
# **What `memify()` does for Python:** This advanced function uses AI to:
#
# - **Infer rule patterns** from your code (e.g., "When implementing iterators, always follow the protocol Guido established")
# - **Connect design philosophy to practice** (e.g., linking "explicit is better than implicit" to your type hinting decisions)

# %% [markdown]
# Now let's see how the system has connected your Python development patterns with established best practices:

# %%
# Search for connections between your async patterns and Python philosophy
results = await cognee.search(
    "How does my AsyncWebScraper implementation align with Python's design principles?",
    query_type=cognee.SearchType.GRAPH_COMPLETION
)
print("Python Pattern Analysis:", results)
# Out:
# 2025-09-07T12:03:10.069706 [info     ] Retrieved 158 nodes and 379 edges in 0.03 seconds [Neo4jAdapter]
#
# 2025-09-07T12:03:10.073335 [info     ] Graph projection completed: 158 nodes, 379 edges in 0.04s [CogneeGraph]
#
# 2025-09-07T12:03:10.606712 [info     ] Vector collection retrieval completed: Retrieved distances from 6 collections in 0.07s [cognee.shared.logging_utils]
# Python Pattern Analysis: ['Analyzing alignment of AsyncWebScraper with Python design principles...']
# /var/folders/b6/fdg52thn3h309cbg6kv5nryc0000gn/T/ipykernel_78432/1153209151.py:2: RuntimeWarning: coroutine 'search' was never awaited
#   results = await cognee.search(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# Now let's see use time awareness feature of cognee to see what are all events that happened between X and Y

# %% [markdown]
# Hm, maybe we are unhappy with the result and want to give feedback to the system so it doesn't give us a bad answer again
