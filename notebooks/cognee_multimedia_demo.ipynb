# %% [markdown]
# ## Cognee GraphRAG with Multimedia files

# %% [markdown]
# ## Load Data
#
# We will use a few sample multimedia files which we have on GitHub for easy access.

# %%
import os
import pathlib

# cognee knowledge graph will be created based on the text
# and description of these files
mp3_file_path = os.path.join(
    os.path.abspath(""),
    "../",
    "examples/data/multimedia/text_to_speech.mp3",
)
png_file_path = os.path.join(
    os.path.abspath(""),
    "../",
    "examples/data/multimedia/example.png",
)

# %% [markdown]
# ## Set environment variables

# %%
import os

if "LLM_API_KEY" not in os.environ:
    os.environ["LLM_API_KEY"] = ""

# "neo4j" or "networkx"
os.environ["GRAPH_DATABASE_PROVIDER"] = "kuzu"
# Not needed if using networkx
# os.environ["GRAPH_DATABASE_URL"]=""
# os.environ["GRAPH_DATABASE_USERNAME"]=""
# os.environ["GRAPH_DATABASE_PASSWORD"]=""

# "pgvector", "qdrant", "weaviate" or "lancedb"
os.environ["VECTOR_DB_PROVIDER"] = "lancedb"
# Not needed if using "lancedb" or "pgvector"
# os.environ["VECTOR_DB_URL"]=""
# os.environ["VECTOR_DB_KEY"]=""

# Relational Database provider "sqlite" or "postgres"
os.environ["DB_PROVIDER"] = "sqlite"

# Database name
os.environ["DB_NAME"] = "cognee_db"

# Postgres specific parameters (Only if Postgres or PGVector is used)
# os.environ["DB_HOST"]="127.0.0.1"
# os.environ["DB_PORT"]="5432"
# os.environ["DB_USERNAME"]="cognee"
# os.environ["DB_PASSWORD"]="cognee"

# %% [markdown]
# ## Run Cognee with multimedia files

# %%
import cognee

# Create a clean slate for cognee -- reset data and system state
await cognee.prune.prune_data()
await cognee.prune.prune_system(metadata=True)

# Add multimedia files and make them available for cognify
await cognee.add([mp3_file_path, png_file_path])

# Create knowledge graph with cognee
await cognee.cognify()
# Out:
# 2025-08-27T13:21:47.304571 [info     ] Deleted Kuzu database files at /Users/daulet/Desktop/dev/cognee-claude/cognee/.cognee_system/databases/cognee_graph_kuzu [cognee.shared.logging_utils]
#
# 2025-08-27T13:21:47.739751 [info     ] Database deleted successfully. [cognee.shared.logging_utils]
#
# Langfuse client is disabled since no public_key was provided as a parameter or environment variable 'LANGFUSE_PUBLIC_KEY'. See our docs: https://langfuse.com/docs/sdk/python/low-level-sdk#initialize-client
# User f5c66ce8-859b-44d4-941a-df6eee1f1d2a has registered.
# 14:21:48 - LiteLLM:INFO: utils.py:3341 -
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
#
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
# EmbeddingRateLimiter initialized: enabled=False, requests_limit=60, interval_seconds=60
#
# 2025-08-27T13:21:54.231053 [info     ] Pipeline run started: `bb1e12db-8d3f-5e80-8615-2444eda4b32a` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:21:54.377156 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-08-27T13:21:54.527056 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-08-27T13:21:54.687437 [info     ] Registered loader: pypdf_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-08-27T13:21:54.687879 [info     ] Registered loader: text_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-08-27T13:21:54.688276 [info     ] Registered loader: image_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-08-27T13:21:54.688542 [info     ] Registered loader: audio_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2025-08-27T13:21:54.688832 [info     ] Registered loader: unstructured_loader [cognee.infrastructure.loaders.LoaderEngine]
# 14:21:56 - LiteLLM:INFO: utils.py:1274 - Wrapper: Completed Call, calling success_handler
#
# Wrapper: Completed Call, calling success_handler
#
# 2025-08-27T13:21:56.382164 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-08-27T13:21:56.534718 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-08-27T13:21:56.688121 [info     ] Pipeline run completed: `bb1e12db-8d3f-5e80-8615-2444eda4b32a` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:21:56.848444 [info     ] Pipeline run started: `bb1e12db-8d3f-5e80-8615-2444eda4b32a` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:21:57.015428 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-08-27T13:21:57.159922 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 14:21:57 - LiteLLM:INFO: utils.py:3341 -
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
#
# LiteLLM completion() model= gpt-5-mini; provider = openai
# 14:22:01 - LiteLLM:INFO: utils.py:1274 - Wrapper: Completed Call, calling success_handler
#
# Wrapper: Completed Call, calling success_handler
#
# 2025-08-27T13:22:01.502324 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-08-27T13:22:01.643327 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-08-27T13:22:01.786439 [info     ] Pipeline run completed: `bb1e12db-8d3f-5e80-8615-2444eda4b32a` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:22:01.951101 [info     ] Ontology file 'None' not found. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2025-08-27T13:22:01.978540 [info     ] Pipeline run started: `52948913-bf39-51ee-a535-e4f140f34c10` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:22:02.126845 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-08-27T13:22:02.304535 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-08-27T13:22:02.471292 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-08-27T13:22:02.632964 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
# 14:22:02 - LiteLLM:INFO: utils.py:3341 -
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
#
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
# 2025-08-27T13:22:29.524347 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:22:29.525119 [info     ] No close match found for 'programmer' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:22:29.525401 [info     ] No close match found for 'object' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:22:29.525697 [info     ] No close match found for 'light bulb' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:22:29.526076 [info     ] No close match found for 'concept' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:22:29.526395 [info     ] No close match found for 'hardware problem' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:22:29.526661 [info     ] No close match found for 'joke' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:22:29.526931 [info     ] No close match found for 'how many programmers does it take to change a light bulb? none, thats a hardware problem.' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:22:29.527282 [info     ] No close match found for 'none' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:22:31.777289 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
# 14:22:31 - LiteLLM:INFO: utils.py:3341 -
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
#
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
# 2025-08-27T13:22:37.705311 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-08-27T13:22:40.603223 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-08-27T13:22:40.769398 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-08-27T13:22:40.984903 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-08-27T13:22:41.128272 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-08-27T13:22:41.275155 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-08-27T13:22:41.436831 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-08-27T13:22:41.606070 [info     ] Pipeline run completed: `52948913-bf39-51ee-a535-e4f140f34c10` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:22:41.767152 [info     ] Pipeline run started: `52948913-bf39-51ee-a535-e4f140f34c10` [run_tasks_with_telemetry()]
#
# 2025-08-27T13:22:41.912031 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2025-08-27T13:22:42.052884 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-08-27T13:22:42.218749 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-08-27T13:22:42.376103 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
# 14:22:42 - LiteLLM:INFO: utils.py:3341 -
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
#
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
# 2025-08-27T13:23:24.700919 [info     ] No close match found for 'text' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:23:24.703407 [info     ] No close match found for 'how many programmers does it take to change a light bulb? none. thats a hardware problem.' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:23:24.703797 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:23:24.704185 [info     ] No close match found for 'programmers' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:23:24.704581 [info     ] No close match found for 'object' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:23:24.704897 [info     ] No close match found for 'light bulb' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:23:24.705215 [info     ] No close match found for 'concept' in category 'classes' [OntologyAdapter]
#
# 2025-08-27T13:23:24.705511 [info     ] No close match found for 'none' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:23:24.705874 [info     ] No close match found for 'hardware problem' in category 'individuals' [OntologyAdapter]
#
# 2025-08-27T13:23:27.372108 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
# 14:23:27 - LiteLLM:INFO: utils.py:3341 -
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
#
# LiteLLM completion() model= gpt-5-mini; provider = openai
#
# 2025-08-27T13:23:33.517938 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2025-08-27T13:23:36.007176 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2025-08-27T13:23:36.181973 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2025-08-27T13:23:36.332093 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2025-08-27T13:23:36.475271 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2025-08-27T13:23:36.717941 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
#
# 2025-08-27T13:23:36.870258 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2025-08-27T13:23:37.018440 [info     ] Pipeline run completed: `52948913-bf39-51ee-a535-e4f140f34c10` [run_tasks_with_telemetry()]
# {UUID('241b64d6-f023-5b87-9a8f-87056f0a442c'): PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('1cde937f-ae7a-5151-a20c-dc3567bee0a9'), dataset_id=UUID('241b64d6-f023-5b87-9a8f-87056f0a442c'), dataset_name='main_dataset', payload=None, data_ingestion_info=[{'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('1cde937f-ae7a-5151-a20c-dc3567bee0a9'), dataset_id=UUID('241b64d6-f023-5b87-9a8f-87056f0a442c'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('692741cd-46e5-5988-85e9-f3901d104b7e')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('1cde937f-ae7a-5151-a20c-dc3567bee0a9'), dataset_id=UUID('241b64d6-f023-5b87-9a8f-87056f0a442c'), dataset_name='main_dataset', payload=None, data_ingestion_info=None), 'data_id': UUID('899de74a-1bef-5afd-a478-1ea944503514')}])}

# %% [markdown]
# ## Query Cognee for summaries related to multimedia files

# %%
from cognee.api.v1.search import SearchType

# Query cognee for summaries of the data in the multimedia files
search_results = await cognee.search(
    query_type=SearchType.SUMMARIES,
    query_text="What is in the multimedia files?",
)

# Display search results
for result_text in search_results:
    print(result_text)
# Out:
# 2025-08-27T13:23:56.768437 [info     ] Starting completion generation for query: 'What is in the multimedia files?' [SummariesRetriever]
#
# 2025-08-27T13:23:56.769790 [info     ] Starting summary retrieval for query: 'What is in the multimedia files?' [SummariesRetriever]
#
# 2025-08-27T13:23:57.168012 [info     ] Found 2 summaries from vector search [SummariesRetriever]
#
# 2025-08-27T13:23:57.168772 [info     ] Returning 2 summary payloads   [SummariesRetriever]
#
# 2025-08-27T13:23:57.169214 [info     ] Returning context with 2 item(s) [SummariesRetriever]
# {'id': '686b9e03-4505-56ec-9295-94c53d4db004', 'created_at': 1756301013713, 'updated_at': 1756301013713, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': "Programmer light-bulb joke: none — it's a hardware problem."}
# {'id': '82343440-bd02-5149-ad3f-80289121146c', 'created_at': 1756300957894, 'updated_at': 1756300957894, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': "Programmers don't change light bulbs — that's a hardware problem."}

# %%
import os
os._exit(0)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
